# %% [markdown]
# # Downloading LOLDataset

# %%
import os
import cv2
import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !gdown https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# !unzip -q lol_dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# To: /content/lol_dataset.zip
# 100% 347M/347M [00:02<00:00, 157MB/s]
# replace lol_dataset/eval15/high/748.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %% [markdown]
# # Creating a TensorFlow Dataset

# %%
random.seed(10)

IMAGE_SIZE = 128
BATCH_SIZE = 4
MAX_TRAIN_IMAGES = 300


def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.cast(image, dtype=tf.float32) / 255.0
    return image


def random_crop(low_image, enhanced_image):
    low_image_shape = tf.shape(low_image)[:2]
    low_w = tf.random.uniform(
        shape=(), maxval=low_image_shape[1] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_h = tf.random.uniform(
        shape=(), maxval=low_image_shape[0] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    enhanced_w = low_w
    enhanced_h = low_h
    low_image_cropped = low_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    enhanced_image_cropped = enhanced_image[
        enhanced_h : enhanced_h + IMAGE_SIZE, enhanced_w : enhanced_w + IMAGE_SIZE
    ]
    return low_image_cropped, enhanced_image_cropped


def load_data(low_light_image_path, enhanced_image_path):
    low_light_image = read_image(low_light_image_path)
    enhanced_image = read_image(enhanced_image_path)
    low_light_image, enhanced_image = random_crop(low_light_image, enhanced_image)
    return low_light_image, enhanced_image


def get_dataset(low_light_images, enhanced_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images, enhanced_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
train_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[:MAX_TRAIN_IMAGES]

val_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
val_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[MAX_TRAIN_IMAGES:]

test_low_light_images = sorted(glob("./lol_dataset/eval15/low/*"))
test_enhanced_images = sorted(glob("./lol_dataset/eval15/high/*"))


train_dataset = get_dataset(train_low_light_images, train_enhanced_images)
val_dataset = get_dataset(val_low_light_images, val_enhanced_images)


print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Train Dataset: <_BatchDataset element_spec=(TensorSpec(shape=(4, None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, None, None, 3), dtype=tf.float32, name=None))>
# Val Dataset: <_BatchDataset element_spec=(TensorSpec(shape=(4, None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, None, None, 3), dtype=tf.float32, name=None))>

# %% [markdown]
# # MIRNet Model

# %% [markdown]
# ## Selective Kernel Feature Fusion

# %%
def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
):
    channels = list(multi_scale_feature_1.shape)[-1]
    combined_feature = layers.Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
    )
    gap = layers.GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
    compact_feature_representation = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)
    feature_descriptor_1 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_2 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_3 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3
    aggregated_feature = layers.Add()([feature_1, feature_2, feature_3])
    return aggregated_feature

# %% [markdown]
# ## Dual Attention Unit

# %%
def spatial_attention_block(input_tensor):
    average_pooling = tf.reduce_max(input_tensor, axis=-1)
    average_pooling = tf.expand_dims(average_pooling, axis=-1)
    max_pooling = tf.reduce_mean(input_tensor, axis=-1)
    max_pooling = tf.expand_dims(max_pooling, axis=-1)
    concatenated = layers.Concatenate(axis=-1)([average_pooling, max_pooling])
    feature_map = layers.Conv2D(1, kernel_size=(1, 1))(concatenated)
    feature_map = tf.nn.sigmoid(feature_map)
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = layers.GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = tf.reshape(average_pooling, shape=(-1, 1, 1, channels))
    feature_activations = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)
    feature_activations = layers.Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)
    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)
    feature_map = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(
        feature_map
    )
    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = layers.Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = layers.Conv2D(channels, kernel_size=(1, 1))(concatenation)
    return layers.Add()([input_tensor, concatenation])

# %% [markdown]
# ## Multi-Scale Residual Block

# %%
def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.MaxPooling2D()(main_branch)
    main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.MaxPooling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.UpSampling2D()(main_branch)
    main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.UpSampling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


# MRB Block
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)
    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)
    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau), level2_dau, up_sampling_module(level3_dau)
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
    )
    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )
    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level2_dau_2, level3_dau_2)
    conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    return layers.Add()([input_tensor, conv])

# %% [markdown]
# ## MIRNet Model

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)
    return layers.Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = keras.Input(shape=[None, None, 3])
    x1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = layers.Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = layers.Add()([input_tensor, conv])
    return keras.Model(input_tensor, output_tensor)


model = mirnet_model(num_rrg=3, num_mrb=2, channels=64)

# %% [markdown]
# # Training

# %%
def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)


optimizer = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer, loss=charbonnier_loss, metrics=[peak_signal_noise_ratio]
)

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_peak_signal_noise_ratio",
            factor=0.5,
            patience=5,
            verbose=1,
            min_delta=1e-7,
            mode="max",
        )
    ],
)

plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()


plt.plot(history.history["peak_signal_noise_ratio"], label="train_psnr")
plt.plot(history.history["val_peak_signal_noise_ratio"], label="val_psnr")
plt.xlabel("Epochs")
plt.ylabel("PSNR")
plt.title("Train and Validation PSNR Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/50
# 75/75 [==============================] - 383s 2s/step - loss: 0.2006 - peak_signal_noise_ratio: 62.1497 - val_loss: 0.1516 - val_peak_signal_noise_ratio: 64.5771 - lr: 1.0000e-04
# Epoch 2/50
# 75/75 [==============================] - 109s 1s/step - loss: 0.1717 - peak_signal_noise_ratio: 63.4584 - val_loss: 0.1268 - val_peak_signal_noise_ratio: 65.7980 - lr: 1.0000e-04
# Epoch 3/50
# 75/75 [==============================] - 109s 1s/step - loss: 0.1702 - peak_signal_noise_ratio: 63.4921 - val_loss: 0.1266 - val_peak_signal_noise_ratio: 65.7321 - lr: 1.0000e-04
# Epoch 4/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1658 - peak_signal_noise_ratio: 63.5088 - val_loss: 0.1250 - val_peak_signal_noise_ratio: 65.7998 - lr: 1.0000e-04
# Epoch 5/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1641 - peak_signal_noise_ratio: 63.7247 - val_loss: 0.1221 - val_peak_signal_noise_ratio: 65.8925 - lr: 1.0000e-04
# Epoch 6/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1592 - peak_signal_noise_ratio: 64.0317 - val_loss: 0.1159 - val_peak_signal_noise_ratio: 66.3753 - lr: 1.0000e-04
# Epoch 7/50
# 75/75 [==============================] - 105s 1s/step - loss: 0.1581 - peak_signal_noise_ratio: 64.0808 - val_loss: 0.1187 - val_peak_signal_noise_ratio: 66.2747 - lr: 1.0000e-04
# Epoch 8/50
# 75/75 [==============================] - 105s 1s/step - loss: 0.1536 - peak_signal_noise_ratio: 64.3390 - val_loss: 0.1207 - val_peak_signal_noise_ratio: 66.3296 - lr: 1.0000e-04
# Epoch 9/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1517 - peak_signal_noise_ratio: 64.5355 - val_loss: 0.1215 - val_peak_signal_noise_ratio: 66.3987 - lr: 1.0000e-04
# Epoch 10/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1555 - peak_signal_noise_ratio: 64.1724 - val_loss: 0.1238 - val_peak_signal_noise_ratio: 66.3489 - lr: 1.0000e-04
# Epoch 11/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1500 - peak_signal_noise_ratio: 64.8833 - val_loss: 0.1350 - val_peak_signal_noise_ratio: 65.8061 - lr: 1.0000e-04
# Epoch 12/50
# 75/75 [==============================] - 109s 1s/step - loss: 0.1497 - peak_signal_noise_ratio: 64.8521 - val_loss: 0.1134 - val_peak_signal_noise_ratio: 67.2136 - lr: 1.0000e-04
# Epoch 13/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1553 - peak_signal_noise_ratio: 64.5124 - val_loss: 0.1154 - val_peak_signal_noise_ratio: 67.0427 - lr: 1.0000e-04
# Epoch 14/50
# 75/75 [==============================] - 109s 1s/step - loss: 0.1471 - peak_signal_noise_ratio: 64.8510 - val_loss: 0.1054 - val_peak_signal_noise_ratio: 67.3477 - lr: 1.0000e-04
# Epoch 15/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1384 - peak_signal_noise_ratio: 65.4349 - val_loss: 0.1089 - val_peak_signal_noise_ratio: 67.4240 - lr: 1.0000e-04
# Epoch 16/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1352 - peak_signal_noise_ratio: 65.2401 - val_loss: 0.1058 - val_peak_signal_noise_ratio: 67.5225 - lr: 1.0000e-04
# Epoch 17/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1329 - peak_signal_noise_ratio: 65.7870 - val_loss: 0.1088 - val_peak_signal_noise_ratio: 67.5600 - lr: 1.0000e-04
# Epoch 18/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1406 - peak_signal_noise_ratio: 65.2818 - val_loss: 0.1043 - val_peak_signal_noise_ratio: 67.4411 - lr: 1.0000e-04
# Epoch 19/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1348 - peak_signal_noise_ratio: 65.6150 - val_loss: 0.1012 - val_peak_signal_noise_ratio: 67.8842 - lr: 1.0000e-04
# Epoch 20/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1344 - peak_signal_noise_ratio: 65.5513 - val_loss: 0.1053 - val_peak_signal_noise_ratio: 67.6511 - lr: 1.0000e-04
# Epoch 21/50
# 75/75 [==============================] - 109s 1s/step - loss: 0.1297 - peak_signal_noise_ratio: 65.8341 - val_loss: 0.1029 - val_peak_signal_noise_ratio: 67.8176 - lr: 1.0000e-04
# Epoch 22/50
# 75/75 [==============================] - 109s 1s/step - loss: 0.1252 - peak_signal_noise_ratio: 66.2354 - val_loss: 0.1028 - val_peak_signal_noise_ratio: 67.7709 - lr: 1.0000e-04
# Epoch 23/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1367 - peak_signal_noise_ratio: 65.5254 - val_loss: 0.1038 - val_peak_signal_noise_ratio: 67.7536 - lr: 1.0000e-04
# Epoch 24/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1321 - peak_signal_noise_ratio: 65.7940 - val_loss: 0.1025 - val_peak_signal_noise_ratio: 67.9972 - lr: 1.0000e-04
# Epoch 25/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1333 - peak_signal_noise_ratio: 65.6008 - val_loss: 0.1029 - val_peak_signal_noise_ratio: 67.9380 - lr: 1.0000e-04
# Epoch 26/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1234 - peak_signal_noise_ratio: 66.2161 - val_loss: 0.1007 - val_peak_signal_noise_ratio: 68.0004 - lr: 1.0000e-04
# Epoch 27/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1219 - peak_signal_noise_ratio: 66.4343 - val_loss: 0.0978 - val_peak_signal_noise_ratio: 68.2703 - lr: 1.0000e-04
# Epoch 28/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1268 - peak_signal_noise_ratio: 66.0915 - val_loss: 0.1038 - val_peak_signal_noise_ratio: 67.7844 - lr: 1.0000e-04
# Epoch 29/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1346 - peak_signal_noise_ratio: 65.7635 - val_loss: 0.1019 - val_peak_signal_noise_ratio: 67.7914 - lr: 1.0000e-04
# Epoch 30/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1225 - peak_signal_noise_ratio: 66.4607 - val_loss: 0.1012 - val_peak_signal_noise_ratio: 68.2204 - lr: 1.0000e-04
# Epoch 31/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1295 - peak_signal_noise_ratio: 65.9299 - val_loss: 0.0966 - val_peak_signal_noise_ratio: 68.4146 - lr: 1.0000e-04
# Epoch 32/50
# 75/75 [==============================] - 105s 1s/step - loss: 0.1299 - peak_signal_noise_ratio: 66.0208 - val_loss: 0.1070 - val_peak_signal_noise_ratio: 67.4005 - lr: 1.0000e-04
# Epoch 33/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1194 - peak_signal_noise_ratio: 66.7851 - val_loss: 0.1003 - val_peak_signal_noise_ratio: 67.9876 - lr: 1.0000e-04
# Epoch 34/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1245 - peak_signal_noise_ratio: 66.3443 - val_loss: 0.0983 - val_peak_signal_noise_ratio: 68.4313 - lr: 1.0000e-04
# Epoch 35/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1245 - peak_signal_noise_ratio: 66.4291 - val_loss: 0.1039 - val_peak_signal_noise_ratio: 68.1638 - lr: 1.0000e-04
# Epoch 36/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1318 - peak_signal_noise_ratio: 65.9339 - val_loss: 0.1093 - val_peak_signal_noise_ratio: 67.3426 - lr: 1.0000e-04
# Epoch 37/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1249 - peak_signal_noise_ratio: 66.2233 - val_loss: 0.1005 - val_peak_signal_noise_ratio: 67.9952 - lr: 1.0000e-04
# Epoch 38/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1296 - peak_signal_noise_ratio: 66.0495 - val_loss: 0.0991 - val_peak_signal_noise_ratio: 67.7268 - lr: 1.0000e-04
# Epoch 39/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1236 - peak_signal_noise_ratio: 66.4200
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 75/75 [==============================] - 108s 1s/step - loss: 0.1236 - peak_signal_noise_ratio: 66.4200 - val_loss: 0.1002 - val_peak_signal_noise_ratio: 67.9581 - lr: 1.0000e-04
# Epoch 40/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1195 - peak_signal_noise_ratio: 66.6750 - val_loss: 0.1107 - val_peak_signal_noise_ratio: 66.7466 - lr: 5.0000e-05
# Epoch 41/50
# 75/75 [==============================] - 105s 1s/step - loss: 0.1147 - peak_signal_noise_ratio: 67.0693 - val_loss: 0.1078 - val_peak_signal_noise_ratio: 67.3160 - lr: 5.0000e-05
# Epoch 42/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1190 - peak_signal_noise_ratio: 66.8637 - val_loss: 0.1077 - val_peak_signal_noise_ratio: 67.2014 - lr: 5.0000e-05
# Epoch 43/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1124 - peak_signal_noise_ratio: 67.1473 - val_loss: 0.1093 - val_peak_signal_noise_ratio: 67.1761 - lr: 5.0000e-05
# Epoch 44/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1179 - peak_signal_noise_ratio: 66.7401
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 75/75 [==============================] - 108s 1s/step - loss: 0.1179 - peak_signal_noise_ratio: 66.7401 - val_loss: 0.1049 - val_peak_signal_noise_ratio: 67.2491 - lr: 5.0000e-05
# Epoch 45/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1194 - peak_signal_noise_ratio: 66.7428 - val_loss: 0.1061 - val_peak_signal_noise_ratio: 67.4360 - lr: 2.5000e-05
# Epoch 46/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1144 - peak_signal_noise_ratio: 67.1297 - val_loss: 0.1045 - val_peak_signal_noise_ratio: 67.5692 - lr: 2.5000e-05
# Epoch 47/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1114 - peak_signal_noise_ratio: 67.3682 - val_loss: 0.1077 - val_peak_signal_noise_ratio: 67.1893 - lr: 2.5000e-05
# Epoch 48/50
# 75/75 [==============================] - 108s 1s/step - loss: 0.1150 - peak_signal_noise_ratio: 66.9119 - val_loss: 0.1107 - val_peak_signal_noise_ratio: 67.2477 - lr: 2.5000e-05
# Epoch 49/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1149 - peak_signal_noise_ratio: 67.0290
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 75/75 [==============================] - 108s 1s/step - loss: 0.1149 - peak_signal_noise_ratio: 67.0290 - val_loss: 0.1064 - val_peak_signal_noise_ratio: 67.4510 - lr: 2.5000e-05
# Epoch 50/50
# 75/75 [==============================] - 104s 1s/step - loss: 0.1145 - peak_signal_noise_ratio: 67.1674 - val_loss: 0.1052 - val_peak_signal_noise_ratio: 67.5461 - lr: 1.2500e-05

# %% [markdown]
# # Saving Model

# %%
import joblib

filename = 'finalized_model.sav'
joblib.dump(model, filename)
# Out:
# ['finalized_model.sav']
